# %%
print("hello world!!")
# Out:
# hello world!!

# %%
x = 6
print(x)
# Out:
# 6

# %%
y = x * 7
print(y)
# Out:
# 42

# %%
# 1) c)
# 2) é uma sequencia de instruções que foram criadas para fazer algo
# 3) interpretador executa o código linha por linha, já o compilador executa todos os codigos ao mesmo tempo.
# 4) a)
# 5) o termo "primt" deve ser escrito "print", além do mais é necessário utilizar ()
# 6) b)
# 7) 
x = 43
x = x + 1
print(x)
# Out:
# 44

# %%
# 7) b)
# 8) CPU = cérebro, memória principal = memória de curto prazo, memória secundária = memória de longo prazo, 
# dispositivo de entrada = audição, visão e etc..., dispositivo de saída = voz
# 9) corrigindo os erros gramaticais utilizados inicialmente
