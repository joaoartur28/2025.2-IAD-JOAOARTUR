# %%
x=1
x=x+1
print(x)
# Out:
# 2

# %%
#while é enquanto, ou seja, enquanto um fator estiver sendo atendido, ele continua rodando.

# %%
n = 5
while n > 0:
   print(n)
   n = n- 1
   print("Lançar!")
# Out:
# 5
# Lançar!
# 4
# Lançar!
# 3
# Lançar!
# 2
# Lançar!
# 1
# Lançar!

# %%
n = 5
while n > 0:
   print(n)
   n = n- 1
print("Lançar!")
# Out:
# 5
# 4
# 3
# 2
# 1
# Lançar!

# %%
# dará um valor infinito
n = 10
while True:
   print(n, end ="")
   n = n - 1
print("Pronto!")

# %%
amigos = ["Jose","Gleice","Sara"]
for amigo in amigos:
    print("Feliz Ano Novo", amigo)
print("Feito!")
# Out:
# Feliz Ano Novo Jose
# Feliz Ano Novo Gleice
# Feliz Ano Novo Sara
# Feito!

# %%
contador = 0
for itervar in [3, 41, 12, 9, 74, 15]:
    contador = contador + 1
print("Contagem: ", contador)
# Out:
# Contagem:  6
