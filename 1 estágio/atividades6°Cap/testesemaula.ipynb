# %%
fruta = "banana"
letra = fruta[1]
print(letra)
fruta[-1]
# Out:
# a
# 'a'

# %%
indice = 0
while indice < len(fruta):
    letra = fruta[indice]
    print(letra)
    indice = indice + 1
# Out:
# b
# a
# n
# a
# n
# a

# %%
for char in fruta:
    print(char)
# Out:
# b
# a
# n
# a
# n
# a

# %%
saudaçao = "alo, mundo"
nova_saudaçao = "o" + saudaçao[1:]
print(nova_saudaçao)
# Out:
# olo, mundo

# %%
palavra = "banana"
contagem = 0
for letra in palavra:
   if letra == "a":
     contagem = contagem + 1
print(contagem)
# Out:
# 3

# %%
fruta =("banana")
letra = fruta[1]
print(letra)
# Out:
# a
