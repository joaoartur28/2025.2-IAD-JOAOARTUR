# %%
fruta = "banana"
letra = fruta[1]
print(letra)
fruta[-1]
# Out:
# a
# 'a'

# %%
indice = 0
while indice < len(fruta):
    letra = fruta[indice]
    print(letra)
    indice = indice + 1
# Out:
# b
# a
# n
# a
# n
# a

# %%
for char in fruta:
    print(char)
# Out:
# b
# a
# n
# a
# n
# a
