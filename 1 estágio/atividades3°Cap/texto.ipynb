# %%
5==5
# Out:
# True

# %%
5==6
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
#o valor de x tem que vir na frente do "x > 0..."
x = 5
x > 0 and x < 10
# Out:
# True

# %%
# % é o resto na divisão
x = 4
x%2==0 or x%3==0
# Out:
# True

# %%
# pode ser representado com x no inicio...
# sempre coloque o "tab" depois do "if" e coloque o ":"
x=100
if x > 0:
    print("x é positivo")
# Out:
# x é positivo

# %%
#...ou pode ser representado com x no final
if x > 0:
    print("x é positivo")
x=90
# Out:
# x é positivo

# %%
if x < 0:
    pass

# %%
x = 3
if x < 10:
    print("pequeno")
# Out:
# pequeno

# %%
if x < 10:
    print("pequeno")
x = 1
# Out:
# pequeno

# %%
x = 3
if x < 10:
    print("pequeno")
print("feito")
# Out:
# pequeno
# feito

# %%
# O  valor de x tem que vir antes para gerar o if, elif e else
x=2
y=3

# %%
if x%2 == 0:
    print("x é par")
else:
    print("x é impar")
# Out:
# x é par

# %%
if x < y:
    print("x é menor que y")
elif x > y:
    print("x é maior que y")
else:
    print("x e y são iguais")
# Out:
# x é menor que y

# %%
# Você tem que definir a variável choice. Nesse caso escolhi input para definir a 
# variável
choice = input("digite sua escolha (a,b ou c): ")

# %%
if choice == "a":
    print("mau palpite")
elif choice == "b":
    print("bom palpite")
elif choice == "c":
    print("perto")
# Out:
# bom palpite

# %%
# Refere-se ao código abaixo
x=91

# %%
if 0 < x:
    if x < 10:
        print("x é um numero positivo de 1 digito")
