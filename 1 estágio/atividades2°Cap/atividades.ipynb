# %%
print(4)
# Out:
# 4

# %%
type("hello world")
# Out:
# str

# %%
type(17)
# Out:
# int

# %%
type(3.2)
# Out:
# float

# %%
print(1,000,000)
# Out:
# 1 0 0

# %%
message = "e agora, para algo completamente diferente"
n = 17
pi = 3.1415

# %%
type(message)
# Out:
# str

# %%
type(pi)
# Out:
# float

# %%
type(n)
# Out:
# int

# %%
print(1)
x = 2
print(x)
# Out:
# 1
# 2

# %%
20+32
# Out:
# 52

# %%
minuto = 59
minuto/60
# Out:
# 0.9833333333333333

# %%
# exercícios =
